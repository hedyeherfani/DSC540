# %% [markdown]
# # This file contains Chapters 7, 8, 10

# %%
import pandas as pd

# %%
df = pd.read_csv('candyhierarchy2017.csv',engine= 'python')
df.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# ...

# %% [markdown]
# # 1) Removing null values

# %%
df.isnull().sum()
# Out:
# Internal ID                    0
# Q1: GOING OUT?               110
# Q2: GENDER                    41
# Q3: AGE                       84
# Q4: COUNTRY                   64
#                             ...
# Q12: MEDIA [Daily Dish]     2375
# Q12: MEDIA [Science]        1098
# Q12: MEDIA [ESPN]           2361
# Q12: MEDIA [Yahoo]          2393
# Click Coordinates (x, y)     855
# Length: 120, dtype: int64

# %%
modified_df = df.fillna(" ")
modified_df.isnull().sum()
# Out:
# Internal ID                 0
# Q1: GOING OUT?              0
# Q2: GENDER                  0
# Q3: AGE                     0
# Q4: COUNTRY                 0
#                            ..
# Q12: MEDIA [Daily Dish]     0
# Q12: MEDIA [Science]        0
# Q12: MEDIA [ESPN]           0
# Q12: MEDIA [Yahoo]          0
# Click Coordinates (x, y)    0
# Length: 120, dtype: int64

# %%
modified_df.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773
# 1     90272821             No       Male      44        USA
# 2     90272829                      Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0
# 1                               NM                MEH
# 2                         Virginia
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0
# 1                                            DESPAIR
# 2
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Q6 | Any full-sized candy bar Q6 | Black Jacks  ... Q8: DESPAIR OTHER  \
# ...

# %% [markdown]
# # 2) Replacing values within the country column so that The United States of America only shows as USA

# %%
# Changing column name to make it easier for me to replace values
modified_df.rename(columns = {'Q4: COUNTRY':'Country'}, inplace = True)

# %%
modified_df.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Country  \
# 0     90258773
# 1     90272821             No       Male      44    USA
# 2     90272829                      Male      49     USA
# 3     90272840             No       Male      40      us
# 4     90272841             No       Male      23     usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0
# 1                               NM                MEH
# 2                         Virginia
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0
# 1                                            DESPAIR
# 2
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Q6 | Any full-sized candy bar Q6 | Black Jacks  ... Q8: DESPAIR OTHER  \
# 0                                                 ...
# ...

# %%
# Replacing values that might be confusing or not continuous from the Country column
modified_df.loc[(modified_df.Country == 'us'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'usa'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'Us'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'Murica'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'United States'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'Usa'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'United staes'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'US'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'United States of America'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'united states'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'unhinged states'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'united states of america'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'US of A'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'Unites States'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'The United States'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'U.S.A.'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'merica'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'america'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'United States'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'Unied States'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'North Carolina'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'u.s.'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'United Statea'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'USA USA USA!!!!'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'Fear and Loathing'),'Country']=''
modified_df.loc[(modified_df.Country == 'murrika'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'United State'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'endland'),'Country']='UK'
modified_df.loc[(modified_df.Country == 'United Statss'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'America'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'canada'),'Country']='Canada'
modified_df.loc[(modified_df.Country == 'United Stated'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'New Jersey'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'New Jersey'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'U.S.'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'Ahem....Amerca'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'Uk'),'Country']='UK'
modified_df.loc[(modified_df.Country == "I pretend to be from Canada, but I am really f..."),'Country']=''
modified_df.loc[(modified_df.Country == 'South africa'),'Country']='South Africa'
modified_df.loc[(modified_df.Country == 'California'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'Trumpistan'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'United Sates'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'United Kingdom'),'Country']='UK'
modified_df.loc[(modified_df.Country == '32'),'Country']=''
modified_df.loc[(modified_df.Country == '45'),'Country']=''
modified_df.loc[(modified_df.Country == 'Pittsburgh'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'USA? Hard to tell anymore..'),'Country']=''
modified_df.loc[(modified_df.Country == "'merica"),'Country']='USA'
modified_df.loc[(modified_df.Country == 'insanity lately'),'Country']=''
modified_df.loc[(modified_df.Country == 'cascadia'),'Country']=''
modified_df.loc[(modified_df.Country == '46'),'Country']=''
modified_df.loc[(modified_df.Country == 'unite states'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'U.K.'),'Country']='UK'
modified_df.loc[(modified_df.Country == 'Earth'),'Country']=''
modified_df.loc[(modified_df.Country == 'Europe'),'Country']=''
modified_df.loc[(modified_df.Country == 'North Carolina '),'Country']='USA'
modified_df.loc[(modified_df.Country == '35'),'Country']=''
modified_df.loc[(modified_df.Country == 'England'),'Country']='UK'
modified_df.loc[(modified_df.Country == 'u.s.a.'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'USAUSAUSA'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'france'),'Country']='France'
modified_df.loc[(modified_df.Country == 'finland'),'Country']='Finlad'
modified_df.loc[(modified_df.Country == 'uk'),'Country']='UK'
modified_df.loc[(modified_df.Country == 'germany'),'Country']='Germany'
modified_df.loc[(modified_df.Country == 'United States '),'Country']='USA'
modified_df.loc[(modified_df.Country == 'United States of America '),'Country']='USA'
modified_df.loc[(modified_df.Country == 'U.K. '),'Country']='UK'
modified_df.loc[(modified_df.Country == 'New York'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'Alaska'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'soviet canuckistan'),'Country']=''
modified_df.loc[(modified_df.Country == 'N. America'),'Country']=''
modified_df.loc[(modified_df.Country == '1'),'Country']=''
modified_df.loc[(modified_df.Country == 'united ststes'),'Country']=''
modified_df.loc[(modified_df.Country == 'u s a'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'Narnia'),'Country']=''
modified_df.loc[(modified_df.Country == 'CANADA'),'Country']='Canada'
modified_df.loc[(modified_df.Country == 'U.S. '),'Country']='USA'
modified_df.loc[(modified_df.Country == "I don't know anymore"),'Country']='USA'
modified_df.loc[(modified_df.Country == 'United kingdom'),'Country']='UK'
modified_df.loc[(modified_df.Country == 'USA! USA! USA!'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'Atlantis'),'Country']=''
modified_df.loc[(modified_df.Country == 'spain'),'Country']='Spain'
modified_df.loc[(modified_df.Country == 'hong kong'),'Country']='Hong Kong'
modified_df.loc[(modified_df.Country == 'United states'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'united States '),'Country']='USA'
modified_df.loc[(modified_df.Country == 'australia'),'Country']='Australia'
modified_df.loc[(modified_df.Country == 'United ststes'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'The United States of America'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'subscribe to dm4uz3 on youtube'),'Country']=''
modified_df.loc[(modified_df.Country == 'usas'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'USAA'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'USSA'),'Country']='USA'
modified_df.loc[(modified_df.Country == 'USa'),'Country']='USA'

# %%
# Making sure that no other values besides USA are appearing in the Country column
print(modified_df.Country.to_string(index=False))
# Out:
#
#                                               USA
#                                                USA
#                                                USA
#                                                USA
#
#                                                USA
#                                             Canada
#                                             Canada
#                                                USA
#
#                                             Canada
#                                                USA
#                                                USA
#                                             Canada
#                                                USA
#                                                USA
#                                                USA
#                                                USA
#                                                USA
#                                                 UK
# ...

# %%
# Saving the updated csv file so I can review it fully 
modified_df.to_csv('UpdatedCandy.csv',index=False)

# %% [markdown]
# # 3)  Creating hierarchial index

# %%
modified_df.reindex(columns =['Q3: AGE','Country','NewCol'])[:2461]
# Out:
#      Q3: AGE Country  NewCol
# 0                        NaN
# 1         44    USA      NaN
# 2         49     USA     NaN
# 3         40     USA     NaN
# 4         23     USA     NaN
# ...      ...     ...     ...
# 2455      24     USA     NaN
# 2456      33     USA     NaN
# 2457      26    USA      NaN
# 2458      58     USA     NaN
# 2459      66     USA     NaN
#
# [2460 rows x 3 columns]

# %%
reindexed = modified_df.reset_index()
multi_fi = reindexed.set_index(['Internal ID','Q2: GENDER'])
multi_fi[:2461]
# Out:
#                         index Q1: GOING OUT? Q3: AGE Country  \
# Internal ID Q2: GENDER
# 90258773                    0
# 90272821    Male            1             No      44    USA
# 90272829    Male            2                     49     USA
# 90272840    Male            3             No      40     USA
# 90272841    Male            4             No      23     USA
# ...                       ...            ...     ...     ...
# 90314359    Male         2455             No      24     USA
# 90314580    Female       2456             No      33     USA
# 90314634    Female       2457             No      26    USA
# 90314658    Male         2458             No      58     USA
# 90314802    Female       2459             No      66     USA
#
#                        Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# Internal ID Q2: GENDER
# 90258773
# 90272821    Male                                     NM                MEH
# ...

# %% [markdown]
# # 4) Reshaping

# %%
result = multi_fi.stack()
result
# Out:
# Internal ID  Q2: GENDER
# 90258773                 index                                      0
#                          Q1: GOING OUT?
#                          Q3: AGE
#                          Country
#                          Q5: STATE, PROVINCE, COUNTY, ETC
#                                                                ...
# 90314802     Female      Q12: MEDIA [Daily Dish]                    1
#                          Q12: MEDIA [Science]
#                          Q12: MEDIA [ESPN]
#                          Q12: MEDIA [Yahoo]
#                          Click Coordinates (x, y)            (19, 26)
# Length: 292740, dtype: object

# %%
# Changing column name to make it easier for me to do group by values
modified_df.rename(columns = {'Q3: AGE':'Age'}, inplace = True)

# %%
# Removing invalid values/characters so that I can do the groupby
modified_df.loc[(modified_df.Age == 'Old enough'),'Age']=''
modified_df.loc[(modified_df.Age == 'old enough'),'Age']=''
modified_df.loc[(modified_df.Age == 'I can remember when Java was a cool new language'),'Age']=''
modified_df.loc[(modified_df.Age == '60+'),'Age']='60'
modified_df.loc[(modified_df.Age == 'your mom'),'Age']=''
modified_df.loc[(modified_df.Age == '59 on the day after Halloween'),'Age']='59'
modified_df.loc[(modified_df.Age == 'MY NAME JEFF'),'Age']=''
modified_df.loc[(modified_df.Age == 'old'),'Age']=''
modified_df.loc[(modified_df.Age == 'ancient'),'Age']=''
modified_df.loc[(modified_df.Age == '46 Halloweens.'),'Age']=''
modified_df.loc[(modified_df.Age == 'sixty-nine'),'Age']='69'
modified_df.loc[(modified_df.Age == '1000'),'Age']=''
modified_df.loc[(modified_df.Age == 'Over 50'),'Age']=''
modified_df.loc[(modified_df.Age == '24-50'),'Age']=''
modified_df.loc[(modified_df.Age == 'Enough'),'Age']=''
modified_df.loc[(modified_df.Age == 'older than dirt'),'Age']=''
modified_df.loc[(modified_df.Age == 'hahahahaha'),'Age']=''
modified_df.loc[(modified_df.Age == '312'),'Age']=''
modified_df.loc[(modified_df.Age == '45-55'),'Age']=''
modified_df.loc[(modified_df.Age == 'no'),'Age']=''
modified_df.loc[(modified_df.Age == 'Many'),'Age']=''
modified_df.loc[(modified_df.Age == 'See question 2'),'Age']=''
modified_df.loc[(modified_df.Age == 'OLD'),'Age']=''
modified_df.loc[(modified_df.Age == '70 1/2'),'Age']='70'
modified_df.loc[(modified_df.Age == '39.4'),'Age']='30'

# %%
print(modified_df.Age.to_string(index=False))
# Out:
#
#   44
#   49
#   40
#   23
#
#   53
#   33
#   40
#   53
#   43
#   56
#   64
#   43
#   37
#   64
#   59
#   48
#   54
#   36
#   45
#   33
#   37
#   49
#   48
#   25
#   34
#   35
#   38
#   58
#   48
#   35
#   50
#   33
#   47
#   16
#
#   52
#   33
#   63
#   34
#   48
#   52
#   52
#   65
#   45
#   41
#   27
#   47
#   47
#   44
#   49
#   31
#   59
#   50
#   34
#   34
#   61
#   44
#   46
#   54
#   56
#   43
#   41
#   46
#   50
#   42
#   62
#   37
#   45
#   53
#   62
#   40
#   40
#   29
#   33
#   34
#   42
#   48
#   39
#   36
#   38
#   32
#   48
#   33
#   38
#   37
#   44
#   31
#   48
#   37
#   28
#   45
#   42
#   69
#   50
#   64
#   42
#   35
#   44
#
#   44
#   42
#   43
#   37
#   47
#   50
#   67
#   33
#   39
#   30
#   25
#   29
#   53
#
#   22
#   50
#   44
#   46
#   26
#   53
#
#   41
#   62
#   48
#   49
#   37
#   63
#   54
#   51
#   42
#   70
#   33
#   67
#   65
#   46
#   48
#   51
#   53
#   42
#   44
#   37
#   43
#   53
#   64
#   47
#   45
# ...

# %% [markdown]
# # 5) Grouping with dicts/series

# %%
new = modified_df.groupby('Internal ID', as_index=False).agg({"Age": "sum"})
new.head()
# Out:
#    Internal ID Age
# 0     90258773
# 1     90272821  44
# 2     90272829  49
# 3     90272840  40
# 4     90272841  23

# %%
new = modified_df.groupby('Internal ID',as_index=False)['Internal ID','Age']
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
new.head()
# Out:
#       Internal ID Age
# 0        90258773
# 1        90272821  44
# 2        90272829  49
# 3        90272840  40
# 4        90272841  23
# ...           ...  ..
# 2455     90314359  24
# 2456     90314580  33
# 2457     90314634  26
# 2458     90314658  58
# 2459     90314802  66
#
# [2460 rows x 2 columns]

# %% [markdown]
# # 6) Split/Apply/Combine

# %%
def top(modified_df, n=5,column= 'Age'):
    return modified_df.sort_values(by=column)[-n:]

# %%
top(modified_df,n=6)
# Out:
#       Internal ID Q1: GOING OUT?          Q2: GENDER Age Country  \
# 705      90275672            Yes                Male   9     USA
# 1054     90277137            Yes                Male   9  Canada
# 451      90274056             No  I'd rather not say  90
# 1411     90279092            Yes                Male  90     USA
# 575      90274994             No  I'd rather not say  99     USA
# 325      90273639             No                Male   ?  Canada
#
#      Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 705                            Merlin                JOY
# 1054                 British Columbia                JOY
# 451                         Sub Earth                MEH
# 1411                         Arkansas                JOY
# 575                                NY                MEH
# 325                  British Columbia            DESPAIR
#
#      Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# ...

# %%
modified_df.groupby('Country').apply(top)
# Out:
#               Internal ID Q1: GOING OUT?          Q2: GENDER Age  Country  \
# Country
#         1652     90281296             No                Male  15
#         2209     90288455             No              Female  44
#         701      90275651             No              Female  45
#         2072     90285987             No                Male  45
#         451      90274056             No  I'd rather not say  90
# ...                   ...            ...                 ...  ..      ...
# USA     127      90273118            Yes                Male  63     USA
#         504      90274333                             Female  70     USA
#         2312     90292940             No                Male  73     USA
# Usa     1171     90277538             No              Female  34     Usa
# canada  110      90273079                               Male  30  canada
#
#              Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# Country
#         1652
# ...
